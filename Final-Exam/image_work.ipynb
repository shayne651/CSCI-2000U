# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy import fftpack
from scipy import misc

# %%
rgb_peppers = plt.imread('peppers.png')
plt.gray()
misc.bytescale(rgb_peppers,cmin=-5.2,cmax=99)
plt.imshow(rgb_peppers)
plt.plot()
# Out:
# []
